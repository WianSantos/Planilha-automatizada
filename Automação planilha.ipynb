# %%
import pyautogui 
import time
import pyperclip

while True:
   try:
      DataHoje = int(pyautogui.prompt('Informe a data de hoje. | Digite neste formato: 29'))
      break
   except ValueError:
      print("Please type an integer value.")
        #abrindo caminho

#troca de turno 
pyautogui.hotkey('win', 'd')#area de trabalho
time.sleep(0.5)
pyautogui.click(114, 579)#clic na area de trabalho
pyautogui.write("128")
pyautogui.press('enter')

time.sleep(12)

pyautogui.click(67, 215)
time.sleep(1.5)
pyautogui.rightClick(67, 215) #click com lado esquedo da aba A
time.sleep(1.5)
pyautogui.click(119, 371)#excluir a aba A
time.sleep(2)

pyautogui.rightClick(184, 216) #click com lado esquedo da aba C
time.sleep(0.5)
pyautogui.click(240, 378)#excluir a aba C
time.sleep(0.5)

pyautogui.rightClick(184, 216) #click com lado esquedo da aba C2
time.sleep(0.5)
pyautogui.click(240, 378)#excluir a aba C2
time.sleep(0.5)

pyautogui.rightClick(239, 214) #click com lado esquedo da aba D
time.sleep(0.5)
pyautogui.click(245, 380)#excluir a aba D
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba F
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba F
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba G
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba G
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba H
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba H
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba I
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba I
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba J
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba J
time.sleep(0.5)

pyautogui.rightClick(376, 216) #click com lado esquedo da aba K
time.sleep(0.5)
pyautogui.click(410, 375)#excluir a aba K
time.sleep(0.5)

pyautogui.rightClick(234, 213) #click com lado esquedo da aba D
time.sleep(0.5)
pyautogui.click(263, 231)#Recortar a aba D
time.sleep(0.5)

pyautogui.rightClick(67, 215) #click com lado esquedo da aba A
time.sleep(0.5)
pyautogui.click(112, 355)#Inserir a aba D na aba A
time.sleep(0.5)

pyautogui.rightClick(67, 215) #click com lado esquedo da aba A
time.sleep(0.5)
pyautogui.click(92, 248)#copiar a aba A 
time.sleep(0.5)

pyautogui.rightClick(67, 215) #click com lado esquedo da aba A
time.sleep(0.5)
pyautogui.click(116, 356)#inserir a aba A copiada na aba A
time.sleep(0.5)

pyautogui.rightClick(247, 217) #click com lado esquedo da aba D
time.sleep(0.5)
pyautogui.click(301, 227)#Recortar a aba D
time.sleep(0.5)

pyautogui.rightClick(176, 212) #click com lado esquedo da aba C
time.sleep(0.5)
pyautogui.click(261, 351)#inserir a aba D na aba C
time.sleep(0.5)

pyautogui.rightClick(304, 211) #click com lado esquedo da aba E
time.sleep(0.5)
pyautogui.click(336, 233)#recortar a aba E
time.sleep(0.5)

pyautogui.rightClick(247, 217) #click com lado esquedo da aba D
time.sleep(0.5)
pyautogui.click(290, 349)#inserir a aba E na aba D
time.sleep(0.5)

pyautogui.rightClick(15, 234) #click com lado esquedo da aba 1
time.sleep(0.5)
pyautogui.click(69, 407)#excluir aba 1
time.sleep(0.5)

pyautogui.click(66, 231)#iclicar na A2
time.sleep(0.5)

pyautogui.hotkey('ctrl', 't')#selecionar tudo
time.sleep(0.5)
pyautogui.hotkey('ctrl', 'c')#copiar tudo

#abrindo o caminho
pyautogui.hotkey('win', 'd')
time.sleep(3)
pyautogui.hotkey('win', 'r')
time.sleep(0.5)
local = (r"C:\Users\wianv\Desktop\PastaTeste")
pyautogui.write(local)
time.sleep(2)
pyautogui.press('enter')
time.sleep(2)
pyautogui.hotkey('win', 'up')
if DataHoje == 1:
    pyautogui.write('Planilha de adicionais 01')
elif DataHoje == 2:
    pyautogui.write('Planilha de adicionais 02')
elif DataHoje == 3:
    pyautogui.write('Planilha de adicionais 03')
elif DataHoje == 4:
    pyautogui.write('Planilha de adicionais 04')
elif DataHoje == 5:
    pyautogui.write('Planilha de adicionais 05')
elif DataHoje == 6:
    pyautogui.write('Planilha de adicionais 06')
elif DataHoje == 7:
    pyautogui.write('Planilha de adicionais 07')
elif DataHoje == 8:
    pyautogui.write('Planilha de adicionais 08')
elif DataHoje == 9:
    pyautogui.write('Planilha de adicionais 09')
elif DataHoje == 10:
    pyautogui.write('Planilha de adicionais 10')
elif DataHoje == 11:
    pyautogui.write('Planilha de adicionais 11')
elif DataHoje == 12:
    pyautogui.write('Planilha de adicionais 12')
elif DataHoje == 13:
    pyautogui.write('Planilha de adicionais 13')
elif DataHoje == 14:
    pyautogui.write('Planilha de adicionais 14')
elif DataHoje == 15:
    pyautogui.write('Planilha de adicionais 15')
elif DataHoje == 16:
    pyautogui.write('Planilha de adicionais 16')
elif DataHoje == 17:
    pyautogui.write('Planilha de adicionais 17')
elif DataHoje == 18:
    pyautogui.write('Planilha de adicionais 18')
elif DataHoje == 19:
    pyautogui.write('Planilha de adicionais 19')
elif DataHoje == 20:
    pyautogui.write('Planilha de adicionais 20')
elif DataHoje == 21:
    pyautogui.write('Planilha de adicionais 21')
elif DataHoje == 22:
    pyautogui.write('Planilha de adicionais 22')
elif DataHoje == 23:
    pyautogui.write('Planilha de adicionais 23')
elif DataHoje == 24:
    pyautogui.write('Planilha de adicionais 24')
elif DataHoje == 25:
    pyautogui.write('Planilha de adicionais 25')
elif DataHoje == 26:
    pyautogui.write('Planilha de adicionais 26')
elif DataHoje == 27:
    pyautogui.write('Planilha de adicionais 27')
elif DataHoje == 28:
    pyautogui.write('Planilha de adicionais 28')
elif DataHoje == 29:
    pyautogui.write('Planilha de adicionais 29')
elif DataHoje == 30:
    pyautogui.write('Planilha de adicionais 31')
time.sleep(2)
pyautogui.press('enter')#abrir planilha
time.sleep(8)
pyautogui.click(295, 703)#abrir segunda planilha
time.sleep(1)
pyautogui.click(155, 291)#linha de baixo 
time.sleep(1)
pyautogui.hotkey('ctrl','v')
time.sleep(3)
pyautogui.click(121, 266)#linha formatação
time.sleep(1)
pyautogui.keyDown('shiftleft')
pyautogui.keyDown('shiftright')
pyautogui.press('right', presses = 6)
pyautogui.click(73, 124)
pyautogui.hotkey('ctrl','down')
time.sleep(0.5)
pyautogui.click(73, 124)
pyautogui.hotkey('ctrl','down')
time.sleep(0.5)
pyautogui.keyUp('shiftleft')
pyautogui.keyUp('shiftright')

# %%
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=73, y=124)
